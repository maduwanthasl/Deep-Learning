# %%
import numpy as np
import tensorflow as tf

# %%
import time

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
shape = 5000

# %%
np_array = np.random.uniform(size = [shape,shape])

# %%
np_array
# Out:
# array([[0.05013693, 0.90452283, 0.65949451, ..., 0.17371938, 0.77885833,
#         0.03236682],
#        [0.30579991, 0.48061534, 0.09160416, ..., 0.66263589, 0.11433791,
#         0.56044215],
#        [0.48622118, 0.01625996, 0.11196873, ..., 0.13871501, 0.60829427,
#         0.17995634],
#        ...,
#        [0.6705506 , 0.02583104, 0.71103042, ..., 0.4872594 , 0.30850892,
#         0.5162748 ],
#        [0.53082351, 0.17825774, 0.17769016, ..., 0.60435287, 0.75305071,
#         0.8650877 ],
#        [0.04979922, 0.16317181, 0.51389981, ..., 0.94547753, 0.50947044,
#         0.29585031]])

# %%
start = time.time()

for i in range(10):
  np.matmul(np_array,np_array)

end = time.time()

time_period = end - start

print(f'{time_period} seconds')
# Out:
# 46.465158462524414 seconds

# %%
tf_array = tf.random.uniform([shape,shape])

# %%
start = time.time()

for i in range(10):
  tf.matmul(tf_array,tf_array)

end = time.time()

time_period = end - start
print(f'{time_period} seconds')
# Out:
# 0.11113977432250977 seconds
