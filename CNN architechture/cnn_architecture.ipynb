# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    ###1st convolution layer
    tf.keras.layers.Conv2D(10,(5,5),activation = "relu",input_shape = (64,64,3)),## filter size
    #1st pooling layer
    tf.keras.layers.MaxPooling2D((3,3),strides=(3,3)),#filter size, stride(x axis , y axis)

    ###2nd convolution layer
    tf.keras.layers.Conv2D(16,(5,5),activation = "relu"),
    #2nd pooling layer
    tf.keras.layers.MaxPooling2D((2,2),strides = (2,2)),

    #flatten layer
    tf.keras.layers.Flatten(),

    #dense layers
    tf.keras.layers.Dense(128,activation = "relu"),
    tf.keras.layers.Dense(16,activation = "relu"),
    tf.keras.layers.Dense(1,activation = "sigmoid")


])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 10)        760
#
#  max_pooling2d (MaxPooling2  (None, 20, 20, 10)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 16)        4016
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 16)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dense_1 (Dense)             (None, 16)                2064
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 138057 (539.29 KB)
# Trainable params: 138057 (539.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
